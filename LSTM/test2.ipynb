# %% [markdown]
# # 第二步：对一个基站中的所有的数据进行预测

# %% [markdown]
# # 环境配置

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/LSTM")
# !ls
# Out:
# BSrf1000.mat  DATA  IMG  test1.ipynb  test2.ipynb  train2.csv  train.csv

# %% [markdown]
# # 数据预处理

# %%
from scipy.io import loadmat
import pandas as pd

m = loadmat("BSrf1000.mat")
print(m["BaseStationnum0"])
df = pd.DataFrame(m["BaseStationnum0"])
# Out:
# [[49 24 17 ...  3  3  3]
#  [49 25 16 ...  3  3  3]
#  [50 24 16 ...  3  3  3]
#  ...
#  [40 20 14 ...  2  2  2]
#  [40 20 13 ...  2  2  2]
#  [40 20 13 ...  2  2  2]]

# %% [markdown]
# ## 显示一下train2.csv文件

# %%
df.to_csv("train2.csv")
print(df)
# Out:
#      0   1   2   3   4   5   6   7   8   ...  11  12  13  14  15  16  17  18  19
# 0    49  24  17  12  10   8   7   6   5  ...   4   4   3   3   3   3   3   3   3
# 1    49  25  16  12  10   8   7   6   5  ...   4   4   3   3   3   3   3   3   3
# 2    50  24  16  12  10   8   7   6   5  ...   4   4   4   3   3   3   3   3   3
# 3    49  25  16  12  10   8   7   6   6  ...   4   4   3   3   3   3   3   3   3
# 4    50  25  16  12  10   8   7   6   5  ...   4   4   4   3   3   3   3   3   3
# 5    49  25  16  12  10   8   7   6   5  ...   4   4   3   3   3   3   3   3   2
# 6    49  25  17  12  10   8   7   6   5  ...   4   4   4   3   3   3   3   2   3
# 7    50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 8    50  25  16  12  10   9   7   6   5  ...   4   4   4   3   3   3   3   3   3
# 9    50  25  17  12  10   8   7   6   5  ...   4   4   4   3   3   3   3   3   3
# 10   50  25  17  13  10   9   7   6   6  ...   4   4   3   3   3   3   3   3   3
# 11   50  25  17  12  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 12   50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 13   50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 14   50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 15   50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 16   50  25  17  12  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 17   50  25  17  13  10   9   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 18   51  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 19   50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 20   50  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 21   51  25  17  13  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 22   50  25  17  13  10   9   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 23   51  25  17  12  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 24   50  25  17  12  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 25   50  25  17  12  10   8   7   6   6  ...   4   4   4   3   3   3   3   3   3
# 26   50  25  17  12  10   8   7   6   5  ...   4   4   4   3   3   3   3   3   3
# 27   50  25  16  12  10   8   7   6   5  ...   4   4   3   3   3   3   3   3   2
# 28   50  25  17  12  10   8   7   6   5  ...   4   4   4   3   3   3   3   3   3
# 29   50  25  17  12  10   8   7   6   5  ...   4   4   3   3   3   3   3   3   2
# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 328  42  21  14  11   8   7   6   5   5  ...   4   3   3   3   3   2   2   2   2
# 329  42  21  14  11   8   7   6   5   5  ...   4   3   3   3   3   3   2   2   2
# 330  42  21  14  10   8   7   6   5   5  ...   4   3   3   3   3   3   2   2   2
# 331  41  21  14  11   8   7   6   5   5  ...   4   3   3   3   3   2   2   2   2
# 332  42  21  14  10   8   7   6   5   5  ...   3   3   3   3   3   2   2   2   2
# 333  41  21  14  10   8   7   6   5   5  ...   4   3   3   3   3   2   2   2   2
# 334  41  21  14  10   8   7   6   5   5  ...   3   3   3   3   3   2   2   2   2
# 335  41  21  14  10   8   7   6   5   5  ...   3   3   3   3   3   2   2   2   2
# 336  40  20  14  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 337  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 338  40  20  13  10   8   7   6   5   5  ...   3   3   3   3   2   2   2   2   2
# 339  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   3   2   2   2   2
# 340  41  20  14  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 341  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   3   2   2   2   2
# 342  40  20  13  10   8   7   6   5   5  ...   3   3   3   3   2   2   2   2   2
# 343  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 344  40  20  14  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 345  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 346  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 347  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 348  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 349  40  20  13  10   8   7   6   5   5  ...   3   3   3   3   2   2   2   2   2
# 350  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 351  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 352  40  20  13  10   8   7   6   5   5  ...   3   3   3   3   2   2   2   2   2
# 353  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 354  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   2   2   2   2   2
# 355  40  20  14  10   8   7   6   5   5  ...   3   3   3   3   3   2   2   2   2
# 356  40  20  13  10   8   7   6   5   4  ...   3   3   3   3   3   2   2   2   2
# 357  40  20  13  10   8   7   6   5   5  ...   3   3   3   3   3   2   2   2   2
#
# [358 rows x 20 columns]

# %% [markdown]
# # 开始进行预测项目

# %%
import os
import numpy
import math
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv
from keras.models import Sequential
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# 添加内容：读取所有的列数来做后续的预测内容
for i in range(1,21):
  # show the data
  dataframe = read_csv("train2.csv",usecols = [i], engine = "python", skipfooter = 3)
  dataset  = dataframe.values
  # change int to float
  dataset = dataset.astype("float32")

  # 后两行为显示图像，实际可删掉
  # plt.plot(dataset)
  # plt.show()

  # 加载数据集，前90%作为训练集，后10%作为测试集
  def creat_dataset(dataset, look_back = 1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
      a = dataset[i: (i + look_back), 0]
      dataX.append(a)
      dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)
  
  # fix random seed for reproducibility
  numpy.random.seed(7)

  # normalize the data
  scaler = MinMaxScaler(feature_range = (0, 1))
  dataset = scaler.fit_transform(dataset)

  # split into train and test set
  train_size  = int(len(dataset) * 0.9)
  test_size = len(dataset) - train_size
  train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

  # use this function to prepare the train and test dataset for model
  look_back = 1
  trainX, trainY = creat_dataset(train, look_back)
  testX, testY = creat_dataset(test, look_back)

  # reshape input to be [samples, time steps, features]
  trainX = numpy.reshape(trainX, (trainX.shape[0], look_back, trainX.shape[1]))
  testX = numpy.reshape(testX, (testX.shape[0], look_back, testX.shape[1]))

  # creat and fit the LSTM network
  model = Sequential()
  model.add(LSTM(4, input_shape = (1, look_back)))
  model.add(Dense(1))
  model.compile(loss='mean_squared_error', optimizer='adam')
  model.fit(trainX, trainY, epochs=20, batch_size=1, verbose=2)

  # make predictions
  trainPredict = model.predict(trainX)
  testPredict = model.predict(testX)

  # invert predictions
  trainPredict = scaler.inverse_transform(trainPredict)
  trainY = scaler.inverse_transform([trainY])
  testPredict = scaler.inverse_transform(testPredict)
  testY = scaler.inverse_transform([testY])

  # shift train predictions for plotting
  trainPredictPlot = numpy.empty_like(dataset)
  trainPredictPlot[:, :] = numpy.nan
  trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

  # shift test predictions for plotting
  testPredictPlot = numpy.empty_like(dataset)
  testPredictPlot[:, :] = numpy.nan
  testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

  
  # plot baseline and predictions
  print("=================================================================")
  print('第' + str(i) + "幅图像")
  plt.plot(scaler.inverse_transform(dataset))
  plt.plot(trainPredictPlot)
  plt.plot(testPredictPlot)
  os.chdir("/content/drive/My Drive/LSTM/IMG/BaseStationnum0")
  plt.savefig(str(i) + ".jpg")
  plt.show()
  os.chdir("/content/drive/My Drive/LSTM")
# Out:
# Epoch 1/20
#  - 9s - loss: 0.1687
# Epoch 2/20
#  - 1s - loss: 0.0264
# Epoch 3/20
#  - 1s - loss: 0.0179
# Epoch 4/20
#  - 1s - loss: 0.0118
# Epoch 5/20
#  - 1s - loss: 0.0068
# Epoch 6/20
#  - 1s - loss: 0.0038
# Epoch 7/20
#  - 1s - loss: 0.0025
# Epoch 8/20
#  - 1s - loss: 0.0021
# Epoch 9/20
#  - 1s - loss: 0.0021
# Epoch 10/20
#  - 1s - loss: 0.0021
# Epoch 11/20
#  - 1s - loss: 0.0021
# Epoch 12/20
#  - 1s - loss: 0.0021
# Epoch 13/20
#  - 1s - loss: 0.0021
# Epoch 14/20
#  - 1s - loss: 0.0021
# Epoch 15/20
#  - 1s - loss: 0.0020
# Epoch 16/20
#  - 1s - loss: 0.0021
# Epoch 17/20
#  - 1s - loss: 0.0021
# Epoch 18/20
#  - 1s - loss: 0.0021
# Epoch 19/20
#  - 1s - loss: 0.0021
# Epoch 20/20
#  - 1s - loss: 0.0021
# =================================================================
# 第1幅图像
# Epoch 1/20
#  - 10s - loss: 0.1762
# Epoch 2/20
#  - 1s - loss: 0.0292
# Epoch 3/20
#  - 1s - loss: 0.0206
# Epoch 4/20
#  - 1s - loss: 0.0147
# Epoch 5/20
#  - 1s - loss: 0.0099
# Epoch 6/20
#  - 1s - loss: 0.0070
# Epoch 7/20
#  - 1s - loss: 0.0057
# Epoch 8/20
#  - 1s - loss: 0.0052
# Epoch 9/20
#  - 1s - loss: 0.0051
# Epoch 10/20
#  - 1s - loss: 0.0049
# Epoch 11/20
#  - 1s - loss: 0.0050
# Epoch 12/20
#  - 1s - loss: 0.0051
# Epoch 13/20
#  - 1s - loss: 0.0049
# Epoch 14/20
#  - 1s - loss: 0.0050
# Epoch 15/20
#  - 1s - loss: 0.0050
# Epoch 16/20
#  - 1s - loss: 0.0051
# Epoch 17/20
#  - 1s - loss: 0.0050
# Epoch 18/20
#  - 1s - loss: 0.0051
# Epoch 19/20
#  - 1s - loss: 0.0050
# Epoch 20/20
#  - 1s - loss: 0.0051
# =================================================================
# 第2幅图像
# Epoch 1/20
#  - 10s - loss: 0.1825
# Epoch 2/20
#  - 1s - loss: 0.0275
# Epoch 3/20
#  - 1s - loss: 0.0199
# Epoch 4/20
#  - 1s - loss: 0.0153
# Epoch 5/20
#  - 1s - loss: 0.0109
# Epoch 6/20
#  - 1s - loss: 0.0081
# Epoch 7/20
#  - 1s - loss: 0.0066
# Epoch 8/20
#  - 1s - loss: 0.0058
# Epoch 9/20
#  - 1s - loss: 0.0056
# Epoch 10/20
#  - 1s - loss: 0.0055
# Epoch 11/20
#  - 1s - loss: 0.0056
# Epoch 12/20
#  - 1s - loss: 0.0056
# Epoch 13/20
#  - 1s - loss: 0.0055
# Epoch 14/20
#  - 1s - loss: 0.0055
# Epoch 15/20
#  - 1s - loss: 0.0056
# Epoch 16/20
#  - 1s - loss: 0.0056
# Epoch 17/20
#  - 1s - loss: 0.0055
# Epoch 18/20
#  - 1s - loss: 0.0055
# Epoch 19/20
#  - 1s - loss: 0.0055
# Epoch 20/20
#  - 1s - loss: 0.0055
# =================================================================
# 第3幅图像
# Epoch 1/20
#  - 10s - loss: 0.1285
# Epoch 2/20
#  - 1s - loss: 0.0275
# Epoch 3/20
#  - 1s - loss: 0.0218
# Epoch 4/20
#  - 1s - loss: 0.0180
# Epoch 5/20
#  - 1s - loss: 0.0148
# Epoch 6/20
#  - 1s - loss: 0.0128
# Epoch 7/20
#  - 1s - loss: 0.0117
# Epoch 8/20
#  - 1s - loss: 0.0112
# Epoch 9/20
#  - 1s - loss: 0.0111
# Epoch 10/20
#  - 1s - loss: 0.0109
# Epoch 11/20
#  - 1s - loss: 0.0110
# Epoch 12/20
#  - 1s - loss: 0.0109
# Epoch 13/20
#  - 1s - loss: 0.0109
# Epoch 14/20
#  - 1s - loss: 0.0109
# Epoch 15/20
#  - 1s - loss: 0.0109
# Epoch 16/20
#  - 1s - loss: 0.0107
# Epoch 17/20
#  - 1s - loss: 0.0109
# Epoch 18/20
#  - 1s - loss: 0.0108
# Epoch 19/20
#  - 1s - loss: 0.0107
# Epoch 20/20
#  - 1s - loss: 0.0108
# =================================================================
# 第4幅图像
# Epoch 1/20
#  - 10s - loss: 0.1540
# Epoch 2/20
#  - 1s - loss: 0.0303
# Epoch 3/20
#  - 1s - loss: 0.0245
# Epoch 4/20
#  - 1s - loss: 0.0206
# Epoch 5/20
#  - 1s - loss: 0.0172
# Epoch 6/20
#  - 1s - loss: 0.0148
# Epoch 7/20
#  - 1s - loss: 0.0135
# Epoch 8/20
#  - 1s - loss: 0.0126
# Epoch 9/20
#  - 1s - loss: 0.0123
# Epoch 10/20
#  - 1s - loss: 0.0120
# Epoch 11/20
#  - 1s - loss: 0.0120
# Epoch 12/20
#  - 1s - loss: 0.0122
# Epoch 13/20
#  - 1s - loss: 0.0119
# Epoch 14/20
#  - 1s - loss: 0.0121
# Epoch 15/20
#  - 1s - loss: 0.0120
# Epoch 16/20
#  - 1s - loss: 0.0121
# Epoch 17/20
#  - 1s - loss: 0.0121
# Epoch 18/20
#  - 1s - loss: 0.0121
# Epoch 19/20
#  - 1s - loss: 0.0120
# Epoch 20/20
#  - 1s - loss: 0.0120
# =================================================================
# 第5幅图像
# Epoch 1/20
#  - 10s - loss: 0.1746
# Epoch 2/20
#  - 1s - loss: 0.0648
# Epoch 3/20
#  - 1s - loss: 0.0509
# Epoch 4/20
#  - 1s - loss: 0.0432
# Epoch 5/20
#  - 1s - loss: 0.0386
# Epoch 6/20
#  - 1s - loss: 0.0360
# Epoch 7/20
#  - 1s - loss: 0.0348
# Epoch 8/20
#  - 1s - loss: 0.0347
# Epoch 9/20
#  - 1s - loss: 0.0344
# Epoch 10/20
#  - 1s - loss: 0.0341
# Epoch 11/20
#  - 1s - loss: 0.0338
# Epoch 12/20
#  - 1s - loss: 0.0335
# Epoch 13/20
#  - 1s - loss: 0.0330
# Epoch 14/20
#  - 1s - loss: 0.0330
# Epoch 15/20
#  - 1s - loss: 0.0330
# Epoch 16/20
#  - 1s - loss: 0.0328
# Epoch 17/20
#  - 1s - loss: 0.0327
# Epoch 18/20
#  - 1s - loss: 0.0325
# Epoch 19/20
#  - 1s - loss: 0.0327
# Epoch 20/20
#  - 1s - loss: 0.0325
# =================================================================
# 第6幅图像
# Epoch 1/20
#  - 11s - loss: 0.1166
# Epoch 2/20
#  - 1s - loss: 0.0420
# Epoch 3/20
#  - 1s - loss: 0.0288
# Epoch 4/20
#  - 1s - loss: 0.0196
# Epoch 5/20
#  - 1s - loss: 0.0137
# Epoch 6/20
#  - 1s - loss: 0.0112
# Epoch 7/20
#  - 1s - loss: 0.0104
# Epoch 8/20
#  - 1s - loss: 0.0102
# Epoch 9/20
#  - 1s - loss: 0.0102
# Epoch 10/20
#  - 1s - loss: 0.0101
# Epoch 11/20
#  - 1s - loss: 0.0101
# Epoch 12/20
#  - 1s - loss: 0.0101
# Epoch 13/20
#  - 1s - loss: 0.0101
# Epoch 14/20
#  - 1s - loss: 0.0101
# Epoch 15/20
#  - 1s - loss: 0.0101
# Epoch 16/20
#  - 1s - loss: 0.0101
# Epoch 17/20
#  - 1s - loss: 0.0098
# Epoch 18/20
#  - 1s - loss: 0.0101
# Epoch 19/20
#  - 1s - loss: 0.0100
# Epoch 20/20
#  - 1s - loss: 0.0101
# =================================================================
# 第7幅图像
# Epoch 1/20
#  - 11s - loss: 0.1286
# Epoch 2/20
#  - 1s - loss: 0.0430
# Epoch 3/20
#  - 1s - loss: 0.0329
# Epoch 4/20
#  - 1s - loss: 0.0258
# Epoch 5/20
#  - 1s - loss: 0.0207
# Epoch 6/20
#  - 1s - loss: 0.0180
# Epoch 7/20
#  - 1s - loss: 0.0167
# Epoch 8/20
#  - 1s - loss: 0.0163
# Epoch 9/20
#  - 1s - loss: 0.0162
# Epoch 10/20
#  - 1s - loss: 0.0161
# Epoch 11/20
#  - 1s - loss: 0.0161
# Epoch 12/20
#  - 1s - loss: 0.0161
# Epoch 13/20
#  - 1s - loss: 0.0162
# Epoch 14/20
#  - 1s - loss: 0.0161
# Epoch 15/20
#  - 1s - loss: 0.0160
# Epoch 16/20
#  - 1s - loss: 0.0161
# Epoch 17/20
#  - 1s - loss: 0.0160
# Epoch 18/20
#  - 1s - loss: 0.0160
# Epoch 19/20
#  - 1s - loss: 0.0160
# Epoch 20/20
#  - 1s - loss: 0.0160
# =================================================================
# 第8幅图像
# Epoch 1/20
#  - 11s - loss: 0.2567
# Epoch 2/20
#  - 1s - loss: 0.0423
# Epoch 3/20
#  - 1s - loss: 0.0368
# Epoch 4/20
#  - 1s - loss: 0.0356
# Epoch 5/20
#  - 1s - loss: 0.0344
# Epoch 6/20
#  - 1s - loss: 0.0338
# Epoch 7/20
#  - 1s - loss: 0.0330
# Epoch 8/20
#  - 1s - loss: 0.0325
# Epoch 9/20
#  - 1s - loss: 0.0324
# Epoch 10/20
#  - 1s - loss: 0.0318
# Epoch 11/20
#  - 1s - loss: 0.0314
# Epoch 12/20
#  - 1s - loss: 0.0319
# Epoch 13/20
#  - 1s - loss: 0.0316
# Epoch 14/20
#  - 1s - loss: 0.0316
# Epoch 15/20
#  - 1s - loss: 0.0315
# Epoch 16/20
#  - 1s - loss: 0.0314
# Epoch 17/20
#  - 1s - loss: 0.0316
# Epoch 18/20
#  - 1s - loss: 0.0315
# Epoch 19/20
#  - 1s - loss: 0.0316
# Epoch 20/20
#  - 1s - loss: 0.0313
# =================================================================
# 第9幅图像
# Epoch 1/20
#  - 11s - loss: 0.0748
# Epoch 2/20
#  - 1s - loss: 0.0233
# Epoch 3/20
#  - 1s - loss: 0.0177
# Epoch 4/20
#  - 1s - loss: 0.0137
# Epoch 5/20
#  - 1s - loss: 0.0113
# Epoch 6/20
#  - 1s - loss: 0.0103
# Epoch 7/20
#  - 1s - loss: 0.0100
# Epoch 8/20
#  - 1s - loss: 0.0098
# Epoch 9/20
#  - 1s - loss: 0.0099
# Epoch 10/20
#  - 1s - loss: 0.0099
# Epoch 11/20
#  - 1s - loss: 0.0099
# Epoch 12/20
#  - 1s - loss: 0.0099
# Epoch 13/20
#  - 1s - loss: 0.0098
# Epoch 14/20
#  - 1s - loss: 0.0098
# Epoch 15/20
#  - 1s - loss: 0.0098
# Epoch 16/20
#  - 1s - loss: 0.0100
# Epoch 17/20
#  - 1s - loss: 0.0098
# Epoch 18/20
#  - 1s - loss: 0.0098
# Epoch 19/20
#  - 1s - loss: 0.0098
# Epoch 20/20
#  - 1s - loss: 0.0097
# =================================================================
# 第10幅图像
# Epoch 1/20
#  - 11s - loss: 0.3211
# Epoch 2/20
#  - 1s - loss: 0.1631
# Epoch 3/20
#  - 1s - loss: 0.1409
# Epoch 4/20
#  - 1s - loss: 0.1339
# Epoch 5/20
#  - 1s - loss: 0.1300
# Epoch 6/20
#  - 1s - loss: 0.1283
# Epoch 7/20
#  - 1s - loss: 0.1275
# Epoch 8/20
#  - 1s - loss: 0.1273
# Epoch 9/20
#  - 1s - loss: 0.1274
# Epoch 10/20
#  - 1s - loss: 0.1271
# Epoch 11/20
#  - 1s - loss: 0.1271
# Epoch 12/20
#  - 1s - loss: 0.1279
# Epoch 13/20
#  - 1s - loss: 0.1270
# Epoch 14/20
#  - 1s - loss: 0.1269
# Epoch 15/20
#  - 1s - loss: 0.1270
# Epoch 16/20
#  - 1s - loss: 0.1268
# Epoch 17/20
#  - 1s - loss: 0.1269
# Epoch 18/20
#  - 1s - loss: 0.1266
# Epoch 19/20
#  - 1s - loss: 0.1273
# Epoch 20/20
#  - 1s - loss: 0.1275
# =================================================================
# 第11幅图像
# Epoch 1/20
#  - 11s - loss: 0.0961
# Epoch 2/20
#  - 1s - loss: 0.0184
# Epoch 3/20
#  - 1s - loss: 0.0181
# Epoch 4/20
#  - 2s - loss: 0.0180
# Epoch 5/20
#  - 1s - loss: 0.0178
# Epoch 6/20
#  - 1s - loss: 0.0176
# Epoch 7/20
#  - 1s - loss: 0.0175
# Epoch 8/20
#  - 1s - loss: 0.0174
# Epoch 9/20
#  - 1s - loss: 0.0173
# Epoch 10/20
#  - 1s - loss: 0.0172
# Epoch 11/20
#  - 1s - loss: 0.0171
# Epoch 12/20
#  - 1s - loss: 0.0169
# Epoch 13/20
#  - 1s - loss: 0.0170
# Epoch 14/20
#  - 1s - loss: 0.0168
# Epoch 15/20
#  - 1s - loss: 0.0167
# Epoch 16/20
#  - 1s - loss: 0.0170
# Epoch 17/20
#  - 1s - loss: 0.0166
# Epoch 18/20
#  - 1s - loss: 0.0168
# Epoch 19/20
#  - 1s - loss: 0.0168
# Epoch 20/20
#  - 1s - loss: 0.0167
# =================================================================
# 第12幅图像
# Epoch 1/20
#  - 12s - loss: 0.3489
# Epoch 2/20
#  - 1s - loss: 0.0706
# Epoch 3/20
#  - 1s - loss: 0.0447
# Epoch 4/20
#  - 1s - loss: 0.0326
# Epoch 5/20
#  - 1s - loss: 0.0260
# Epoch 6/20
#  - 1s - loss: 0.0230
# Epoch 7/20
#  - 1s - loss: 0.0221
# Epoch 8/20
#  - 1s - loss: 0.0220
# Epoch 9/20
#  - 1s - loss: 0.0220
# Epoch 10/20
#  - 1s - loss: 0.0219
# Epoch 11/20
#  - 1s - loss: 0.0218
# Epoch 12/20
#  - 1s - loss: 0.0217
# Epoch 13/20
#  - 1s - loss: 0.0219
# Epoch 14/20
#  - 1s - loss: 0.0220
# Epoch 15/20
#  - 1s - loss: 0.0217
# Epoch 16/20
#  - 1s - loss: 0.0220
# Epoch 17/20
#  - 1s - loss: 0.0218
# Epoch 18/20
#  - 1s - loss: 0.0220
# Epoch 19/20
#  - 1s - loss: 0.0219
# Epoch 20/20
#  - 1s - loss: 0.0219
# =================================================================
# 第13幅图像
# Epoch 1/20
#  - 12s - loss: 0.3264
# Epoch 2/20
#  - 1s - loss: 0.1619
# Epoch 3/20
#  - 1s - loss: 0.1416
# Epoch 4/20
#  - 1s - loss: 0.1352
# Epoch 5/20
#  - 1s - loss: 0.1319
# Epoch 6/20
#  - 1s - loss: 0.1305
# Epoch 7/20
#  - 1s - loss: 0.1288
# Epoch 8/20
#  - 1s - loss: 0.1290
# Epoch 9/20
#  - 1s - loss: 0.1291
# Epoch 10/20
#  - 1s - loss: 0.1290
# Epoch 11/20
#  - 1s - loss: 0.1288
# Epoch 12/20
#  - 1s - loss: 0.1285
# Epoch 13/20
#  - 1s - loss: 0.1294
# Epoch 14/20
#  - 1s - loss: 0.1288
# Epoch 15/20
#  - 1s - loss: 0.1293
# Epoch 16/20
#  - 1s - loss: 0.1291
# Epoch 17/20
#  - 1s - loss: 0.1290
# Epoch 18/20
#  - 1s - loss: 0.1295
# Epoch 19/20
#  - 1s - loss: 0.1289
# Epoch 20/20
#  - 1s - loss: 0.1283
# =================================================================
# 第14幅图像
# Epoch 1/20
#  - 12s - loss: 0.0923
# Epoch 2/20
#  - 1s - loss: 0.0775
# Epoch 3/20
#  - 1s - loss: 0.0659
# Epoch 4/20
#  - 1s - loss: 0.0560
# Epoch 5/20
#  - 1s - loss: 0.0500
# Epoch 6/20
#  - 1s - loss: 0.0465
# Epoch 7/20
#  - 1s - loss: 0.0453
# Epoch 8/20
#  - 1s - loss: 0.0450
# Epoch 9/20
#  - 1s - loss: 0.0447
# Epoch 10/20
#  - 1s - loss: 0.0448
# Epoch 11/20
#  - 1s - loss: 0.0447
# Epoch 12/20
#  - 1s - loss: 0.0448
# Epoch 13/20
#  - 1s - loss: 0.0448
# Epoch 14/20
#  - 1s - loss: 0.0447
# Epoch 15/20
#  - 1s - loss: 0.0447
# Epoch 16/20
#  - 1s - loss: 0.0444
# Epoch 17/20
#  - 1s - loss: 0.0451
# Epoch 18/20
#  - 1s - loss: 0.0446
# Epoch 19/20
#  - 1s - loss: 0.0446
# Epoch 20/20
#  - 1s - loss: 0.0450
# =================================================================
# 第15幅图像
# Epoch 1/20
#  - 12s - loss: 0.3858
# Epoch 2/20
#  - 1s - loss: 0.0125
# Epoch 3/20
#  - 1s - loss: 0.0078
# Epoch 4/20
#  - 1s - loss: 0.0077
# Epoch 5/20
#  - 1s - loss: 0.0078
# Epoch 6/20
#  - 1s - loss: 0.0077
# Epoch 7/20
#  - 1s - loss: 0.0077
# Epoch 8/20
#  - 1s - loss: 0.0077
# Epoch 9/20
#  - 1s - loss: 0.0076
# Epoch 10/20
#  - 1s - loss: 0.0076
# Epoch 11/20
#  - 1s - loss: 0.0075
# Epoch 12/20
#  - 1s - loss: 0.0075
# Epoch 13/20
#  - 1s - loss: 0.0072
# Epoch 14/20
#  - 1s - loss: 0.0074
# Epoch 15/20
#  - 1s - loss: 0.0074
# Epoch 16/20
#  - 1s - loss: 0.0073
# Epoch 17/20
#  - 1s - loss: 0.0073
# Epoch 18/20
#  - 1s - loss: 0.0073
# Epoch 19/20
#  - 1s - loss: 0.0072
# Epoch 20/20
#  - 1s - loss: 0.0071
# =================================================================
# 第16幅图像
# Epoch 1/20
#  - 12s - loss: 0.3939
# Epoch 2/20
#  - 1s - loss: 0.0527
# Epoch 3/20
#  - 1s - loss: 0.0459
# Epoch 4/20
#  - 1s - loss: 0.0460
# Epoch 5/20
#  - 1s - loss: 0.0457
# Epoch 6/20
#  - 1s - loss: 0.0458
# Epoch 7/20
#  - 1s - loss: 0.0456
# Epoch 8/20
#  - 1s - loss: 0.0456
# Epoch 9/20
#  - 1s - loss: 0.0458
# Epoch 10/20
#  - 1s - loss: 0.0454
# Epoch 11/20
#  - 1s - loss: 0.0455
# Epoch 12/20
#  - 1s - loss: 0.0456
# Epoch 13/20
#  - 1s - loss: 0.0455
# Epoch 14/20
#  - 1s - loss: 0.0455
# Epoch 15/20
#  - 1s - loss: 0.0452
# Epoch 16/20
#  - 1s - loss: 0.0455
# Epoch 17/20
#  - 1s - loss: 0.0451
# Epoch 18/20
#  - 1s - loss: 0.0455
# Epoch 19/20
#  - 1s - loss: 0.0454
# Epoch 20/20
#  - 1s - loss: 0.0452
# =================================================================
# 第17幅图像
# Epoch 1/20
#  - 12s - loss: 0.3723
# Epoch 2/20
#  - 1s - loss: 0.0780
# Epoch 3/20
#  - 1s - loss: 0.0602
# Epoch 4/20
#  - 1s - loss: 0.0544
# Epoch 5/20
#  - 1s - loss: 0.0500
# Epoch 6/20
#  - 1s - loss: 0.0472
# Epoch 7/20
#  - 1s - loss: 0.0459
# Epoch 8/20
#  - 1s - loss: 0.0450
# Epoch 9/20
#  - 1s - loss: 0.0448
# Epoch 10/20
#  - 1s - loss: 0.0445
# Epoch 11/20
#  - 1s - loss: 0.0447
# Epoch 12/20
#  - 1s - loss: 0.0447
# Epoch 13/20
#  - 1s - loss: 0.0447
# Epoch 14/20
#  - 1s - loss: 0.0447
# Epoch 15/20
#  - 1s - loss: 0.0446
# Epoch 16/20
#  - 1s - loss: 0.0446
# Epoch 17/20
#  - 1s - loss: 0.0445
# Epoch 18/20
#  - 1s - loss: 0.0443
# Epoch 19/20
#  - 1s - loss: 0.0448
# Epoch 20/20
#  - 1s - loss: 0.0444
# =================================================================
# 第18幅图像
# Epoch 1/20
#  - 13s - loss: 0.3426
# Epoch 2/20
#  - 1s - loss: 0.1005
# Epoch 3/20
#  - 1s - loss: 0.0715
# Epoch 4/20
#  - 1s - loss: 0.0599
# Epoch 5/20
#  - 1s - loss: 0.0547
# Epoch 6/20
#  - 1s - loss: 0.0523
# Epoch 7/20
#  - 1s - loss: 0.0513
# Epoch 8/20
#  - 1s - loss: 0.0513
# Epoch 9/20
#  - 1s - loss: 0.0510
# Epoch 10/20
#  - 1s - loss: 0.0507
# Epoch 11/20
#  - 1s - loss: 0.0512
# Epoch 12/20
#  - 1s - loss: 0.0510
# Epoch 13/20
#  - 1s - loss: 0.0510
# Epoch 14/20
#  - 1s - loss: 0.0510
# Epoch 15/20
#  - 1s - loss: 0.0510
# Epoch 16/20
#  - 1s - loss: 0.0512
# Epoch 17/20
#  - 1s - loss: 0.0505
# Epoch 18/20
#  - 1s - loss: 0.0511
# Epoch 19/20
#  - 1s - loss: 0.0510
# Epoch 20/20
#  - 1s - loss: 0.0509
# =================================================================
# 第19幅图像
# Epoch 1/20
#  - 13s - loss: 0.3320
# Epoch 2/20
#  - 1s - loss: 0.1456
# Epoch 3/20
#  - 1s - loss: 0.1194
# Epoch 4/20
#  - 1s - loss: 0.1110
# Epoch 5/20
#  - 1s - loss: 0.1070
# Epoch 6/20
#  - 1s - loss: 0.1046
# Epoch 7/20
#  - 1s - loss: 0.1039
# Epoch 8/20
#  - 1s - loss: 0.1031
# Epoch 9/20
#  - 1s - loss: 0.1037
# Epoch 10/20
#  - 1s - loss: 0.1036
# Epoch 11/20
#  - 1s - loss: 0.1033
# Epoch 12/20
#  - 1s - loss: 0.1038
# Epoch 13/20
#  - 1s - loss: 0.1037
# Epoch 14/20
#  - 1s - loss: 0.1031
# Epoch 15/20
#  - 1s - loss: 0.1036
# Epoch 16/20
#  - 1s - loss: 0.1036
# Epoch 17/20
#  - 1s - loss: 0.1035
# Epoch 18/20
#  - 1s - loss: 0.1034
# Epoch 19/20
#  - 1s - loss: 0.1037
# Epoch 20/20
#  - 1s - loss: 0.1037
# =================================================================
# 第20幅图像
